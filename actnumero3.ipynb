# %% [markdown]
# # Actividad número 3

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.7 MB 45.1 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
# %ls
# Out:
# 00_00_binder.ipynb                    clase2.ipynb
# 00_00_primer_pasos.ipynb              coches.csv
# 01_01_data_types.ipynb                cwurData.csv
# 01_02_read_iloc_unique_groupby.ipynb  data.csv
# 02_00_data_wrangling.ipynb            headbrain.csv
# 02_01_null_display.ipynb              mic2.xlsx
# 02_02_basic_math.ipynb                mic.xlsx
# adult.csv                             movies.csv
# airline_data.csv                      nhanes_2015_2016.csv
# antropometria00.csv                   pokemon.csv
# antropometria-dataset.csv             README.md
# Book3.csv                             requirements.txt.txt
# Canada.xlsx                           sample_pivot.csv
# Cartwheeldata.csv                     tips.csv
# census.csv                            weight-height.csv

# %%
df=pd.read_csv('antropometria-dataset.csv')

# %%
my_pivot=pd.pivot_table(df,
                        index= 'desc_ent',
                       values= 'peso',
                       aggfunc= 'mean',
                       columns= 'sexo',
                       margins= True
                       )
my_pivot
# Out:
# sexo                                     1          2        All
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292  66.357786
# BAJA CALIFORNIA                  71.391818  65.893667  68.467270
# BAJA CALIFORNIA SUR              75.561015  68.168959  71.809198
# CAMPECHE                         68.622637  62.920493  65.418475
# CHIAPAS                          58.365222  57.096111  57.613775
# CHIHUAHUA                        68.892642  64.815295  66.656005
# COAHUILA DE ZARAGOZA             68.873094  67.467348  68.154142
# COLIMA                           70.998878  66.978393  68.743648
# DISTRITO FEDERAL                 69.460661  61.654128  65.119273
# DURANGO                          68.846451  64.400031  66.354922
# GUANAJUATO                       65.008000  63.100995  63.936390
# GUERRERO                         62.611437  58.899850  60.466315
# HIDALGO                          61.747958  58.972554  59.995917
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
#Se puede deducir con base en los datos proporcionados que el estado donde la gente pesa más es en Baja
#California Sur, mientras que en contraste, el estado con el promedio de peso más pequeño es Chiapas.
#En relación a los géneros, el hombre pesa más en Baja California Sur, y la mujer en Sonora.
#Mientras que, igualmente con los géneros, tanto hombre como mujer pesa menos en Chiapas.

# %%
dataFrame=pd.read_csv('adult.csv')
pivote=pd.pivot_table(dataFrame,
                      index= 'marital-status',
                      aggfunc=['count']
                      )
pivote
# Out:
#                         count                                      \
#                           age capital-gain capital-loss education
# marital-status
#  Divorced                4443         4443         4443      4443
#  Married-AF-spouse         23           23           23        23
#  Married-civ-spouse     14976        14976        14976     14976
#  Married-spouse-absent    418          418          418       418
#  Never-married          10683        10683        10683     10683
#  Separated               1025         1025         1025      1025
#  Widowed                  993          993          993       993
#  test_category_female       1            1            1         1
#  test_category_male         2            2            2         2
#
#                                                                            \
#                        education-num fnlwgt hours-per-week native-country
# marital-status
# ...
