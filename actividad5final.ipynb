# %% [markdown]
# # Actividad número 5

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.3 MB/s eta 0:00:01    |▏                               | 71 kB 3.8 MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 15.7 MB 45.7 MB/s eta 0:00:01B 45.7 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 4.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 53.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 48.0 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df= pd.read_csv('antropometria-dataset.csv')

# %%
pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 38.2 MB 152 kB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.lmplot(x='peso',
           y='cintura',
          data=df
          )
plt.title('Scatter plot of Peso vs Cintura')
# Out:
# Text(0.5, 1.0, 'Scatter plot of Peso vs Cintura')

# %%
sns.boxplot(data=df.loc[:,['edad']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['meses']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['peso']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['ropa']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['talla']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['cintura']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['cadera']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['sistol']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df.loc[:,['diastol']])
# Out:
# <AxesSubplot:>

# %%
edad_list=df['edad'].plot(kind='hist')

# %%
month_hist=df['meses'].plot(kind='hist')

# %%
peso_hist=df['peso'].plot(kind='hist')

# %%
ropa_hist=df['ropa'].plot(kind='hist')

# %%
talla_hist=df['talla'].plot(kind='hist')

# %%
cintura_hist=df['cintura'].plot(kind='hist')

# %%
cadera_hist=df['cadera'].plot(kind='hist')

# %%
sistol_hist=df['sistol'].plot(kind='hist')

# %%
diastol_hist=df['diastol'].plot(kind='hist')

# %%
age_line=df['edad'].plot(kind='line')

# %%
meses_line=df['meses'].plot(kind='line')

# %%
peso_line=df['peso'].plot(kind='line')

# %%
ropa_line=df['ropa'].plot(kind='line')

# %%
talla_line=df['talla'].plot(kind='line')

# %%
cintura_line=df['cintura'].plot(kind='line')

# %%
cadera_line=df['cadera'].plot(kind='line')

# %%
sistol_line=df['sistol'].plot(kind='line')

# %%
diastol_line=df['diastol'].plot(kind='line')

# %%
sns.histplot(df['edad'],
             bins=20,
             kde=True
            ).set_title('Histograma de edad')
plt.show()

# %%
sns.histplot(df['meses'],
             bins=20,
             kde=True
            ).set_title('Histograma de meses')
plt.show()

# %%
sns.histplot(df['peso'],
             bins=20,
             kde=True
            ).set_title('Histograma de peso')
plt.show()

# %%
sns.histplot(df['ropa'],
             bins=20,
             kde=True
            ).set_title('Histograma de ropa')
plt.show()

# %%
sns.histplot(df['talla'],
             bins=20,
             kde=True
            ).set_title('Histograma de talla')
plt.show()

# %%
sns.histplot(df['cintura'],
             bins=20,
             kde=True
            ).set_title('Histograma de cintura')
plt.show()

# %%
sns.histplot(df['cadera'],
             bins=20,
             kde=True
            ).set_title('Histograma de cadera')
plt.show()

# %%
sns.histplot(df['sistol'],
             bins=20,
             kde=True
            ).set_title('Histograma de sistol')
plt.show()

# %%
sns.histplot(df['diastol'],
             bins=20,
             kde=True
            ).set_title('Histograma de diastol')
plt.show()

# %%
sns.boxplot(x=df['sexo'],
            y=df['edad']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['meses']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['peso']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['ropa']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['talla']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['cintura']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['cadera']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['sistol']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['sexo'],
            y=df['diastol']
           ).set_title('Box plot de edad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Preguntas
#1: Peso, talla, cintura y cadera son relativamente simétricas
#mientras que sistol y diastol son igualmente simétricas pero
#un poco menos. Por la parte de edad, están sesgadas a la izquierda.
#2: En absolutamente todas las variables hay valores atípicos.
#por ejemplo, en edad un valor atípico es de 104.
#3: Que mientras vaya aumentando el peso, va aumentando la 
#medida de cintura.
#4: En la parte de hasta arriba hay algunos valores atípicos
#y en la parte inferior hay una medida donde una persona que
#pesa mucho tiene una medida de cintura baja.
