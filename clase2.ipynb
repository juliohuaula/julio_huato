# %% [markdown]
# # Clase 2: Tipos de datos

# %%
import numpy as np

# %%
type (-3)
# Out:
# int

# %%
x = 'nombre 1'

# %%
x
# Out:
# 'nombre 1'

# %%
pip install numpy
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 4.9 MB/s eta 0:00:01:00:01��███████▎    | 13.4 MB 4.9 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import math

# %%
print (math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type(math.pi/math.pi)
# Out:
# float

# %%
una_lista= [1,3,'nombre',math.pi,True,5<=3,1==3,3==3,None]

# %%
una_lista
# Out:
# [1, 3, 'nombre', 3.141592653589793, True, False, False, True, None]

# %%
print(una_lista)
# Out:
# [1, 3, 'nombre', 3.141592653589793, True, False, False, True, None]

# %%
str_list=['first','second','third','fourth']

# %%
str_list
# Out:
# ['first', 'second', 'third', 'fourth']

# %%
str_list.sort()

# %%
str_list
# Out:
# ['first', 'fourth', 'second', 'third']

# %%
numbers=[1,2,3,4,5,6]
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers[0]
# Out:
# 1

# %%
numbers[:4]
# Out:
# [1, 2, 3, 4]

# %%
sum(numbers)
# Out:
# 21

# %%
len(numbers)
# Out:
# 6

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for i in una_lista:
    print (i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_117/700100775.py in <module>
# ----> 1 for i in una_lista:
#       2     print (i)
#
# NameError: name 'una_lista' is not defined

# %%
x = 6
y= 7

if x < y: 
        print('{} es menor q {}'.format(x,y))
else:
    print('{} es mayor que {}'.format(x,y))
# Out:
# 6 es menor q 7
